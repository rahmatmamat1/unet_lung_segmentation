# %% [markdown]
# # Testing TensorFlow Serving

# %%
# !pip install grpcio==1.42.0 tensorflow-serving-api==2.7.0
# Out:
# Collecting grpcio==1.42.0
#   Using cached grpcio-1.42.0-cp39-cp39-win_amd64.whl (3.3 MB)
# Collecting tensorflow-serving-api==2.7.0
#   Using cached tensorflow_serving_api-2.7.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: six>=1.5.2 in c:\users\5290\anaconda3\lib\site-packages (from grpcio==1.42.0) (1.16.0)
# Requirement already satisfied: tensorflow<3,>=2.7.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow-serving-api==2.7.0) (2.9.1)
# Requirement already satisfied: protobuf>=3.6.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow-serving-api==2.7.0) (3.19.4)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.1.2)
# Requirement already satisfied: setuptools in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (58.0.4)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.2.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.26.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.9.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.9.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.4.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.12)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.0.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.9.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.2.0)
# Requirement already satisfied: packaging in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (21.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (4.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.12.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.20.3)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (14.0.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\5290\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.37.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.6.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.26.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.3.7)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\5290\anaconda3\lib\site-packages (from tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.0.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\5290\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\5290\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\5290\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (5.1.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\5290\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\5290\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\5290\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.6.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\5290\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\5290\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\5290\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\5290\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2022.9.24)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\5290\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (2.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\5290\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\5290\anaconda3\lib\site-packages (from packaging->tensorflow<3,>=2.7.0->tensorflow-serving-api==2.7.0) (3.0.4)
# Installing collected packages: grpcio, tensorflow-serving-api
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.46.3
#     Uninstalling grpcio-1.46.3:
#       Successfully uninstalled grpcio-1.46.3
# Successfully installed grpcio-1.42.0 tensorflow-serving-api-2.7.0

# %%
import tensorflow as tf
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Defining Function for Custom Object

# %%
def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def iou(y_true, y_pred):
    intersection = keras.sum(keras.abs(y_true * y_pred))
    sum_ = keras.sum(keras.square(y_true)) + keras.sum(keras.square(y_pred))
    jac = (intersection) / (sum_ - intersection)
    return jac

# %%
model = tf.keras.models.load_model('./unet_lung_seg.hdf5', 
                                   custom_objects={'dice_coef': dice_coef,'dice_coef_loss': dice_coef_loss, 'iou':iou})

# %%
model

# %% [markdown]
# #### save model for tensorflow serving

# %%
tf.saved_model.save(model, 'unet_lung_model')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 23). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: unet_lung_model\assets
# INFO:tensorflow:Assets written to: unet_lung_model\assets

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 512, 512, 32  320         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 512, 512, 32  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 32  9248        ['activation[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 512, 512, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 32  0           ['activation_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 256, 256, 32  0           ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 64  18496       ['dropout[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 256, 256, 64  0           ['conv2d_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 64  36928       ['activation_2[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 256, 256, 64  0           ['conv2d_3[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64  0          ['activation_3[0][0]']
#                                 )
#
#  dropout_1 (Dropout)            (None, 128, 128, 64  0           ['max_pooling2d_1[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 12  73856       ['dropout_1[0][0]']
#                                 8)
#
#  activation_4 (Activation)      (None, 128, 128, 12  0           ['conv2d_4[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 12  147584      ['activation_4[0][0]']
#                                 8)
#
#  activation_5 (Activation)      (None, 128, 128, 12  0           ['conv2d_5[0][0]']
#                                 8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['activation_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 64, 64, 128)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 256)  295168      ['dropout_2[0][0]']
#
#  activation_6 (Activation)      (None, 64, 64, 256)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 256)  590080      ['activation_6[0][0]']
#
#  activation_7 (Activation)      (None, 64, 64, 256)  0           ['conv2d_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['activation_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 32, 32, 256)  0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 512)  1180160     ['dropout_3[0][0]']
#
#  activation_8 (Activation)      (None, 32, 32, 512)  0           ['conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 512)  2359808     ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 32, 32, 512)  0           ['conv2d_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 256)  524544     ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 64, 64, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'activation_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 64, 64, 512)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 64, 64, 256)  1179904     ['dropout_4[0][0]']
#
#  activation_10 (Activation)     (None, 64, 64, 256)  0           ['conv2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 64, 64, 256)  590080      ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 256)  0           ['conv2d_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 128, 128, 12  131200     ['activation_11[0][0]']
#  spose)                         8)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_1[0][0]',
#                                 6)                                'activation_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 128, 128, 25  0           ['concatenate_1[0][0]']
#                                 6)
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 12  295040      ['dropout_5[0][0]']
#                                 8)
#
#  activation_12 (Activation)     (None, 128, 128, 12  0           ['conv2d_12[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 12  147584      ['activation_12[0][0]']
#                                 8)
#
#  activation_13 (Activation)     (None, 128, 128, 12  0           ['conv2d_13[0][0]']
#                                 8)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 256, 256, 64  32832      ['activation_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_2[0][0]',
#                                 8)                                'activation_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 256, 256, 12  0           ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  73792       ['dropout_6[0][0]']
#                                 )
#
#  activation_14 (Activation)     (None, 256, 256, 64  0           ['conv2d_14[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  36928       ['activation_14[0][0]']
#                                 )
#
#  activation_15 (Activation)     (None, 256, 256, 64  0           ['conv2d_15[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 512, 512, 32  8224       ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'activation_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 512, 512, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 512, 512, 32  18464       ['dropout_7[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 512, 512, 32  0           ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 512, 512, 32  9248        ['activation_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 512, 512, 32  0           ['conv2d_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 512, 512, 1)  33          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
image = cv2.imread('image/CHNCXR_0300_0.png')
mask_image = cv2.imread('image/CHNCXR_0300_0_mask.png', cv2.IMREAD_GRAYSCALE)

# %%
fig, axs = plt.subplots(1, 2, figsize=(10, 10))

axs[0].set_title("Image")
axs[0].imshow(image)
axs[1].set_title("Mask")
axs[1].imshow(mask_image)

# %% [markdown]
# #### Function for visualization

# %%
def add_colored_mask(image, mask_image):
    mask_image_color = cv2.cvtColor(mask_image, cv2.COLOR_GRAY2BGR)
    mask = cv2.bitwise_and(mask_image_color, mask_image_color, mask=mask_image)
    mask_coord = np.where(mask!=[0,0,0])
    mask[mask_coord[0],mask_coord[1],:]=[255,0,0]
    ret = cv2.addWeighted(image, 0.7, mask, 0.3, 0)
    return ret

def load_image(img_file, target_size=(256,256)):
    img_gray = cv2.cvtColor(img_file, cv2.COLOR_BGR2GRAY)
    img = img_gray / 255
    img = cv2.resize(img, target_size)
    img = np.reshape(img, img.shape + (1,))
    img = np.reshape(img,(1,) + img.shape)
    return img

# %%
img = load_image(image, target_size=(512,512))
img.shape
# Out:
# (1, 512, 512, 1)

# %%
plt.imshow(img[0])

# %% [markdown]
# ## Testing loaded model

# %%
pred = model.predict(img)
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
plt.imshow(pred[0])

# %%
# denormalize prediction
pred_1 = (pred[0][:, :, 0] * 255.).astype(np.uint8)

# %%
plt.imshow(pred_1)

# %%
image_test = cv2.imread('image/CHNCXR_0300_0.png')
mask_image_test = cv2.imread('image/CHNCXR_0300_0_mask.png')

fig, axs = plt.subplots(1, 2, figsize=(10, 10))
axs[0].set_title("Image")
axs[0].imshow(image_test)
axs[1].set_title("Mask")
axs[1].imshow(add_colored_mask(image_test, pred_1.reshape(512,512)))

# %% [markdown]
# ## Testing tensorflow serving

# %% [markdown]
# #### download image

# %%
import urllib.request
import numpy as np

url = 'https://raw.githubusercontent.com/rahmatmamat1/unet_lung_segmentation/main/chest_xray.png'

with urllib.request.urlopen(url) as url:
    img_array = np.asarray(bytearray(url.read()), dtype=np.uint8)
    image = cv2.imdecode(img_array, cv2.IMREAD_COLOR)

# %%
img = load_image(image, target_size=(512,512))

# %%
import grpc

from tensorflow_serving.apis import predict_pb2
from tensorflow_serving.apis import prediction_service_pb2_grpc

from proto import np_to_protobuf

# %% [markdown]
# #### Predict using Tensorflow serving

# %%
host = 'localhost:8500'

channel = grpc.insecure_channel(host)

stub = prediction_service_pb2_grpc.PredictionServiceStub(channel)

# %%
pb_request = predict_pb2.PredictRequest()

pb_request.model_spec.name = 'unet_lung_model'
pb_request.model_spec.signature_name = 'serving_default'

pb_request.inputs['input_1'].CopyFrom(np_to_protobuf(img.astype(np.float32)))
pb_response = stub.Predict(pb_request, timeout=20.0)
preds = pb_response.outputs['conv2d_18'].float_val
# preds = pb_response.outputs['conv2d_18']

# %%
pred_arr = np.array(list(preds))

# %%
pred_arr = np.reshape(pred_arr, (512, 512))

# %%
pred_arr.shape
# Out:
# (512, 512)

# %%
plt.imshow(pred_arr)

# %%
image_test.shape, pred_arr.shape
# Out:
# ((512, 512, 3), (512, 512))

# %%
pred_1 = (pred_arr * 255.).astype(np.uint8)

# %%
plt.imshow(add_colored_mask(image, pred_1))
# Out:
# (512, 512, 3)
